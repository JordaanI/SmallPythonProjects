# %%
from Funcs import *

# %%
test(1000,100,training(1000))
# Out:
# Training on 100000 shapes.
# Average square area: 5628.22.
# Average triangle area: 5658.49.
# 78.858% is the average correct guesses for these weights
